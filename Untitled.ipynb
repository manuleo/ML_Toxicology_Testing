# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rmse_binary
# Out:
# [0, 0, 0.576, 0.576, 0.312, 0.272]

# %%
plt.figure(figsize=(10,8))
methods=['Random','Majority','Uniform','KNN','MF']
types=['Binary Acc','Multiclass Acc', 'Binary RMSE', 'Multiclass RMSE']
pos = np.arange(len(methods))
bar_width = 0.2
acc_binary=[0.498, 0.585, 0.505, 0.902, 0.906]
rmse_binary=[0, 0, 0.576, 0.312, 0.272]
acc_multiclass = [0.207, 0.253, 0.206, 0.741, 0.662]
rmse_multiclass = [0, 0, 1.759, 0.688, 0.637]
 
# plt.bar(pos,acc_binary,bar_width,color='blue',edgecolor='black')
# plt.bar(pos+bar_width,acc_multiclass,bar_width,color='green',edgecolor='black')
plt.bar(pos+2*bar_width,rmse_binary,bar_width,color='orange',edgecolor='black')
plt.bar(pos+3*bar_width,rmse_multiclass,bar_width,color='red',edgecolor='black')

plt.xticks(pos+2*bar_width, methods)
plt.xlabel('Methods', fontsize=16)
plt.ylabel('RMSE/Accuracy', fontsize=16)
plt.title('Accuracy/RMSE Null models + finals',fontsize=18)
plt.legend(types,loc=2)
plt.show()
